# %%
# %%bash
#
# # Do we have GPU support?
# nvidia-smi > /dev/null 2>&1
# if [ $? -eq 0 ]; then
#   # check if we have nvidia-docker
#   NVIDIA_DOCKER=`rpm -qa | grep -c nvidia-docker2`
#   if [ $NVIDIA_DOCKER -eq 0 ]; then
#     # Install nvidia-docker2
#     DOCKER_VERSION=`yum list docker | tail -1 | awk '{print $2}' | head -c 2`
#
#     if [ $DOCKER_VERSION -eq 17 ]; then
#       DOCKER_PKG_VERSION='17.09.1ce-1.111.amzn1'
#       NVIDIA_DOCKER_PKG_VERSION='2.0.3-1.docker17.09.1.ce.amzn1'
#     else
#       DOCKER_PKG_VERSION='18.06.1ce-3.17.amzn1'
#       NVIDIA_DOCKER_PKG_VERSION='2.0.3-1.docker18.06.1.ce.amzn1'
#     fi
#
#     sudo yum -y remove docker
#     sudo yum -y install docker-$DOCKER_PKG_VERSION
#
#     sudo /etc/init.d/docker start
#
#     curl -s -L https://nvidia.github.io/nvidia-docker/amzn1/nvidia-docker.repo | sudo tee /etc/yum.repos.d/nvidia-docker.repo
#     sudo yum install -y nvidia-docker2-$NVIDIA_DOCKER_PKG_VERSION
#     sudo cp daemon.json /etc/docker/daemon.json
#     sudo pkill -SIGHUP dockerd
#     echo "installed nvidia-docker2"
#   else
#     echo "nvidia-docker2 already installed. We are good to go!"
#   fi
# fi
#
# # This is common for both GPU and CPU instances
#
# # check if we have docker-compose
# docker-compose version >/dev/null 2>&1
# if [ $? -ne 0 ]; then
#   # install docker compose
#   pip install docker-compose
# fi
#
# # check if we need to configure our docker interface
# SAGEMAKER_NETWORK=`docker network ls | grep -c sagemaker-local`
# if [ $SAGEMAKER_NETWORK -eq 0 ]; then
#   docker network create --driver bridge sagemaker-local
# fi
#
# # Notebook instance Docker networking fixes
# RUNNING_ON_NOTEBOOK_INSTANCE=`sudo iptables -S OUTPUT -t nat | grep -c 169.254.0.2`
#
# # Get the Docker Network CIDR and IP for the sagemaker-local docker interface.
# SAGEMAKER_INTERFACE=br-`docker network ls | grep sagemaker-local | cut -d' ' -f1`
# DOCKER_NET=`ip route | grep $SAGEMAKER_INTERFACE | cut -d" " -f1`
# DOCKER_IP=`ip route | grep $SAGEMAKER_INTERFACE | cut -d" " -f12`
#
# # check if both IPTables and the Route Table are OK.
# IPTABLES_PATCHED=`sudo iptables -S PREROUTING -t nat | grep -c 169.254.0.2`
# ROUTE_TABLE_PATCHED=`sudo ip route show table agent | grep -c $SAGEMAKER_INTERFACE`
#
# if [ $RUNNING_ON_NOTEBOOK_INSTANCE -gt 0 ]; then
#
#   if [ $ROUTE_TABLE_PATCHED -eq 0 ]; then
#     # fix routing
#     sudo ip route add $DOCKER_NET via $DOCKER_IP dev $SAGEMAKER_INTERFACE table agent
#   else
#     echo "SageMaker instance route table setup is ok. We are good to go."
#   fi
#
#   if [ $IPTABLES_PATCHED -eq 0 ]; then
#     sudo iptables -t nat -A PREROUTING  -i $SAGEMAKER_INTERFACE -d 169.254.169.254/32 -p tcp -m tcp --dport 80 -j DNAT --to-destination 169.254.0.2:9081
#     echo "iptables for Docker setup done"
#   else
#     echo "SageMaker instance routing for Docker is ok. We are good to go!"
#   fi
# fi
# Out:
# nvidia-docker2 already installed. We are good to go!
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %% [markdown]
# # ResNet CIFAR-10 with tensorboard
#
# This notebook shows how to use TensorBoard, and how the training job writes checkpoints to a external bucket.
# The model used for this notebook is a ResNet model, trained with the CIFAR-10 dataset.
# See the following papers for more background:
#
# [Deep Residual Learning for Image Recognition](https://arxiv.org/pdf/1512.03385.pdf) by Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun, Dec 2015.
#
# [Identity Mappings in Deep Residual Networks](https://arxiv.org/pdf/1603.05027.pdf) by Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun, Jul 2016.

# %% [markdown]
# ### Set up the environment

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
# role = 'SageMakerRole'

# %% [markdown]
# ### Download the CIFAR-10 dataset
# Downloading the test and training data will take around 5 minutes.

# %%
import utils

utils.cifar10_download()
# Out:
# FloatProgress(value=0.0)
# >> Downloading cifar-10-binary.tar.gz
# Successfully downloaded cifar-10-binary.tar.gz 170052171 bytes.

# %% [markdown]
# ### Upload the data to a S3 bucket

# %%
# inputs = sagemaker_session.upload_data(path='/tmp/cifar10_data', key_prefix='data/DEMO-cifar10')
inputs = 's3://sagemaker-us-west-2-369233609183/data/DEMO-cifar10'

# %% [markdown]
# **sagemaker_session.upload_data** will upload the CIFAR-10 dataset from your machine to a bucket named **sagemaker-{region}-{*your aws account number*}**, if you don't have this bucket yet, sagemaker_session will create it for you.

# %% [markdown]
# ### Complete source code
# - [source_dir/resnet_model.py](source_dir/resnet_model.py): ResNet model
# - [source_dir/resnet_cifar_10.py](source_dir/resnet_cifar_10.py): main script used for training and hosting

# %% [markdown]
# ## Create a training job using the sagemaker.TensorFlow estimator
# ## THIS IS LOCAL MODE

# %%
from sagemaker.tensorflow import TensorFlow


source_dir = os.path.join(os.getcwd(), 'source_dir')
estimator = TensorFlow(entry_point='benchmark_main.py', framework_version='1.11', py_version='py3',
                       source_dir=source_dir,
                       role=role,
                       hyperparameters={'model': 'resnet50', 'dist_strat': ''},
#                                         'training':'/opt/ml/input/data/training'},
                       train_instance_count=1, train_instance_type='local_gpu')

estimator.fit(inputs)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-scriptmode-2018-11-20-00-36-36-090
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-9-c06699274bf1> in <module>()
#      10                        train_instance_count=1, train_instance_type='local_gpu')
#      11
# ---> 12 estimator.fit(inputs)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit(self, inputs, wait, logs, job_name, run_tensorboard_locally)
#     314                 tensorboard.join()
#     315         else:
# --> 316             fit_super()
#     317
#     318     @classmethod
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/tensorflow/estimator.py in fit_super()
#     293
#     294         def fit_super():
# --> 295             super(TensorFlow, self).fit(inputs, wait, logs, job_name)
#     296
#     297         if run_tensorboard_locally and wait is False:
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name)
#     213         self._prepare_for_training(job_name=job_name)
#     214
# --> 215         self.latest_training_job = _TrainingJob.start_new(self, inputs)
#     216         if wait:
#     217             self.latest_training_job.wait(logs=logs)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs)
#     457                                           resource_config=config['resource_config'], vpc_config=config['vpc_config'],
#     458                                           hyperparameters=hyperparameters, stop_condition=config['stop_condition'],
# --> 459                                           tags=estimator.tags, metric_definitions=estimator.metric_definitions)
#     460
#     461         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, image, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions)
#     281         LOGGER.info('Creating training-job with name: {}'.format(job_name))
#     282         LOGGER.debug('train request: {}'.format(json.dumps(train_request, indent=4)))
# --> 283         self.sagemaker_client.create_training_job(**train_request)
#     284
#     285     def tune(self, job_name, strategy, objective_type, objective_metric_name,
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#      72         training_job = _LocalTrainingJob(container)
#      73         hyperparameters = kwargs['HyperParameters'] if 'HyperParameters' in kwargs else {}
# ---> 74         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#      75
#      76         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#      68         self.state = self._TRAINING
#      69
# ---> 70         self.model_artifacts = self.container.train(input_data_config, output_data_config, hyperparameters, job_name)
#      71         self.end = datetime.datetime.now()
#      72         self.state = self._COMPLETED
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     119         compose_command = self._compose()
#     120
# --> 121         _ecr_login_if_needed(self.sagemaker_session.boto_session, self.image)
#     122         process = subprocess.Popen(compose_command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#     123
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/local/image.py in _ecr_login_if_needed(boto_session, image)
#     668
#     669     ecr = boto_session.client('ecr')
# --> 670     auth = ecr.get_authorization_token(registryIds=[image.split('.')[0]])
#     671     authorization_data = auth['authorizationData'][0]
#     672
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     318                     "%s() only accepts keyword arguments." % py_operation_name)
#     319             # The "self" in this scope is referring to the BaseClient.
# --> 320             return self._make_api_call(operation_name, kwargs)
#     321
#     322         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     622             error_code = parsed_response.get("Error", {}).get("Code")
#     623             error_class = self.exceptions.from_code(error_code)
# --> 624             raise error_class(parsed_response, operation_name)
#     625         else:
#     626             return parsed_response
#
# ClientError: An error occurred (503) when calling the GetAuthorizationToken operation (reached max retries: 4): Service Unavailable

# %% [markdown]
# # ON SAGEMAKER

# %%
from sagemaker.tensorflow import TensorFlow


source_dir = os.path.join(os.getcwd(), 'source_dir')
estimator = TensorFlow(entry_point='benchmark_main.py', framework_version='1.11', py_version='py3',
                       source_dir=source_dir,
                       role=role,
                       hyperparameters={'model': 'resnet50', 'dist_strat': ''},
#                                         'training':'/opt/ml/input/data/training'},
                       train_instance_count=2, train_instance_type='ml.p2.xlarge')

estimator.fit(inputs)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524
# 2018-11-20 01:48:30 Starting - Starting the training job...
# 2018-11-20 01:48:31 Starting - Launching requested ML instances......
# 2018-11-20 01:49:35 Starting - Preparing the instances for training.........
# 2018-11-20 01:51:23 Downloading - Downloading input data..
# 2018-11-20 01:51:40,983 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-20 01:51:41,489 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "dist_strat": "",
#         "model": "resnet50",
#         "model_dir": "s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz",
#     "module_name": "benchmark_main",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "benchmark_main.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"dist_strat":"","model":"resnet50","model_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"}
# SM_USER_ENTRY_POINT=benchmark_main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=benchmark_main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"dist_strat":"","model":"resnet50","model_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz","module_name":"benchmark_main","network_interface_name":"ethwe","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"benchmark_main.py"}
# SM_USER_ARGS=["--dist_strat","","--model","resnet50","--model_dir","s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"]
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_DIST_STRAT=
# SM_HP_MODEL=resnet50
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python benchmark_main.py --dist_strat  --model resnet50 --model_dir s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model
#
#
# I1120 01:51:45.709517 140126770882304 tf_logging.py:115] Benchmark on resnet50 model...
#
# 2018-11-20 01:51:51 Training - Training image download completed. Training in progress.I1120 01:51:49.731195 140126770882304 tf_logging.py:115] Using synthetic dataset...
# 2018-11-20 01:51:52,443 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2018-11-20 01:51:52,921 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "dist_strat": "",
#         "model": "resnet50",
#         "model_dir": "s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "job_name": "sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz",
#     "module_name": "benchmark_main",
#     "network_interface_name": "ethwe",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "ethwe"
#     },
#     "user_entry_point": "benchmark_main.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HPS={"dist_strat":"","model":"resnet50","model_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"}
# SM_USER_ENTRY_POINT=benchmark_main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=benchmark_main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"dist_strat":"","model":"resnet50","model_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/source/sourcedir.tar.gz","module_name":"benchmark_main","network_interface_name":"ethwe","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"ethwe"},"user_entry_point":"benchmark_main.py"}
# SM_USER_ARGS=["--dist_strat","","--model","resnet50","--model_dir","s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model"]
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_DIST_STRAT=
# SM_HP_MODEL=resnet50
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python benchmark_main.py --dist_strat  --model resnet50 --model_dir s3://sagemaker-us-west-2-369233609183/sagemaker-tensorflow-scriptmode-2018-11-20-01-48-29-524/model
#
#
# I1120 01:51:56.868843 140218971571968 tf_logging.py:115] Benchmark on resnet50 model...
# W1120 01:51:58.518591 140126770882304 tf_logging.py:125] You are accessing attribute optimizerof theDistributedCallbackModel that may not have been setcorrectly.
# W1120 01:51:58.613870 140126770882304 tf_logging.py:120] 'cpuinfo' not imported. CPU info will not be logged.
# W1120 01:51:58.615265 140126770882304 tf_logging.py:120] 'psutil' not imported. Memory info will not be logged.
# I1120 01:51:58.615376 140126770882304 tf_logging.py:115] Benchmark run: {'model_name': 'resnet50', 'dataset': {'name': 'ImageNet_Synthetic'}, 'machine_config': {'gpu_info': {'count': 1, 'model': 'Tesla K80'}}, 'test_id': None, 'run_date': '2018-11-20T01:51:58.613268Z', 'tensorflow_version': {'version': '1.11.0', 'git_hash': 'v1.11.0-0-gc19e29306c'}, 'tensorflow_environment_variables': [{'name': 'TF_CPP_MIN_LOG_LEVEL', 'value': '1'}, {'name': 'TF_TENSORRT_VERSION', 'value': '4.1.2'}], 'run_parameters': [{'name': 'batch_size', 'long_value': 32}, {'name': 'num_eval_images', 'long_value': 50}, {'name': 'num_train_images', 'long_value': 1000}, {'name': 'synthetic_data', 'bool_value': 'True'}, {'name': 'train_epochs', 'long_value': 2}]}
# W1120 01:51:58.615740 140126770882304 tf_logging.py:125] Your input callback is not one of the predefined Callbacks that supports DistributionStrategy. You might encounter an error if you access one of the model's attributes as part of the callback since these attributes are not set. You can access each of the individual distributed models using the `_grouped_model` attribute of your original model.
# W1120 01:51:58.615841 140126770882304 tf_logging.py:125] Your input callback is not one of the predefined Callbacks that supports DistributionStrategy. You might encounter an error if you access one of the model's attributes as part of the callback since these attributes are not set. You can access each of the individual distributed models using the `_grouped_model` attribute of your original model.
# I1120 01:52:00.775417 140218971571968 tf_logging.py:115] Using synthetic dataset...
# W1120 01:52:08.862095 140218971571968 tf_logging.py:125] You are accessing attribute optimizerof theDistributedCallbackModel that may not have been setcorrectly.
# W1120 01:52:08.954484 140218971571968 tf_logging.py:120] 'cpuinfo' not imported. CPU info will not be logged.
# W1120 01:52:08.955565 140218971571968 tf_logging.py:120] 'psutil' not imported. Memory info will not be logged.
# I1120 01:52:08.955675 140218971571968 tf_logging.py:115] Benchmark run: {'model_name': 'resnet50', 'dataset': {'name': 'ImageNet_Synthetic'}, 'machine_config': {'gpu_info': {'count': 1, 'model': 'Tesla K80'}}, 'test_id': None, 'run_date': '2018-11-20T01:52:08.953965Z', 'tensorflow_version': {'version': '1.11.0', 'git_hash': 'v1.11.0-0-gc19e29306c'}, 'tensorflow_environment_variables': [{'name': 'TF_CPP_MIN_LOG_LEVEL', 'value': '1'}, {'name': 'TF_TENSORRT_VERSION', 'value': '4.1.2'}], 'run_parameters': [{'name': 'batch_size', 'long_value': 32}, {'name': 'num_eval_images', 'long_value': 50}, {'name': 'num_train_images', 'long_value': 1000}, {'name': 'synthetic_data', 'bool_value': 'True'}, {'name': 'train_epochs', 'long_value': 2}]}
# W1120 01:52:08.955979 140218971571968 tf_logging.py:125] Your input callback is not one of the predefined Callbacks that supports DistributionStrategy. You might encounter an error if you access one of the model's attributes as part of the callback since these attributes are not set. You can access each of the individual distributed models using the `_grouped_model` attribute of your original model.
# W1120 01:52:08.956084 140218971571968 tf_logging.py:125] Your input callback is not one of the predefined Callbacks that supports DistributionStrategy. You might encounter an error if you access one of the model's attributes as part of the callback since these attributes are not set. You can access each of the individual distributed models using the `_grouped_model` attribute of your original model.
# Epoch 1/2
# Epoch 1/2
# I1120 01:52:19.334379 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value':
140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 10, 'timestamp': '2018-11-20T01:52:25.932923Z', 'extras': []}
# I1120 01:52:26.666082 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 20.812762377164955, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:26.665993Z', 'extras': []}
# I1120 01:52:26.666357 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.61343454299678, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:26.666323Z', 'extras': []}
# I1120 01:52:26.666593 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:26.666483Z', 'extras': []}
# I1120 01:52:26.666742 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:26.666706Z', 'extras': []}
# I1120 01:52:27.401808 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 21.75831453587522, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:27.401720Z', 'extras': []}
# I1120 01:52:27.402126 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.49444611694831, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:27.402089Z', 'extras': []}
# I1120 01:52:27.402267 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:27.402235Z', 'extras': []}
# I1120 01:52:27.402414 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:27.402382Z', 'extras': []}
# I1120 01:52:28.134346 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 22.6321123443215, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:28.134256Z', 'extras': []}
# I1120 01:52:28.134616 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.68384106650002, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:28.134584Z', 'extras': []}
# I1120 01:52:28.134773 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:28.134742Z', 'extras': []}
# I1120 01:52:28.134921 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:28.134887Z', 'extras': []}
# I1120 01:52:28.868730 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 23.436669749359915, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:28.868636Z', 'extras': []}
# I1120 01:52:28.868997 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.57407198187143, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:28.868964Z', 'extras': []}
# I1120 01:52:28.869277 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:28.869240Z', 'extras': []}
# I1120 01:52:28.869444 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:28.869408Z', 'extras': []}
# I1120 01:52:27.315670 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 3.781108588983412, 'unit': None, 'global_step': 1, 'timestamp': '2018-11-20T01:52:27.315599Z', 'extras': []}
# I1120 01:52:27.315960 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 3.7811094411382262, 'unit': None, 'global_step': 1, 'timestamp': '2018-11-20T01:52:27.315924Z', 'extras': []}
# I1120 01:52:27.316149 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 1, 'timestamp': '2018-11-20T01:52:27.316116Z', 'extras': []}
# I1120 01:52:27.316292 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 1, 'timestamp': '2018-11-20T01:52:27.316259Z', 'extras': []}
# I1120 01:52:28.047192 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 6.960518433084129, 'unit': None, 'global_step': 2, 'timestamp': '2018-11-20T01:52:28.047122Z', 'extras': []}
# I1120 01:52:28.047426 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.740287402864254, 'unit': None, 'global_step': 2, 'timestamp': '2018-11-20T01:52:28.047395Z', 'extras': []}
# I1120 01:52:28.047585 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 2, 'timestamp': '2018-11-20T01:52:28.047552Z', 'extras': []}
# I1120 01:52:28.047760 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 2, 'timestamp': '2018-11-20T01:52:28.047724Z', 'extras': []}
# I1120 01:52:28.780292 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 9.669795927012819, 'unit': None, 'global_step': 3, 'timestamp': '2018-11-20T01:52:28.780226Z', 'extras': []}
# I1120 01:52:28.780531 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.650057335981046, 'unit': None, 'global_step': 3, 'timestamp': '2018-11-20T01:52:28.780498Z', 'extras': []}
# I1120 01:52:28.780683 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 3, 'timestamp': '2018-11-20T01:52:28.780650Z', 'extras': []}
# I1120 01:52:28.780835 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 3, 'timestamp': '2018-11-20T01:52:28.780803Z', 'extras': []}
# I1120 01:52:29.512296 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 12.0077065516268, 'unit': None, 'global_step': 4, 'timestamp': '2018-11-20T01:52:29.512226Z', 'extras': []}
# I1120 01:52:29.512528 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.71584027390773, 'unit': None, 'global_step': 4, 'timestamp': '2018-11-20T01:52:29.512494Z', 'extras': []}
# I1120 01:52:29.512665 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 4, 'timestamp': '2018-11-20T01:52:29.512635Z', 'extras': []}
# I1120 01:52:29.512809 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 4, 'timestamp': '2018-11-20T01:52:29.512776Z', 'extras': []}
# I1120 01:52:29.602164 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 24.182846022859874, 'unit': None, 'global_step': 15, 'timestamp': '2018-11-20T01:52:29.602073Z', 'extras': []}
# I1120 01:52:29.602432 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.630220631832984, 'unit': None, 'global_step': 15, 'timestamp': '2018-11-20T01:52:29.602400Z', 'extras': []}
# I1120 01:52:29.602579 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 15, 'timestamp': '2018-11-20T01:52:29.602546Z', 'extras': []}
# I1120 01:52:29.602728 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step':
140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 26.686863652523783, 'unit': None, 'global_step': 19, 'timestamp': '2018-11-20T01:52:32.536037Z', 'extras': []}
# I1120 01:52:32.536411 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.583637057954036, 'unit': None, 'global_step': 19, 'timestamp': '2018-11-20T01:52:32.536374Z', 'extras': []}
# I1120 01:52:32.536538 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 19, 'timestamp': '2018-11-20T01:52:32.536514Z', 'extras': []}
# I1120 01:52:32.536681 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 19, 'timestamp': '2018-11-20T01:52:32.536648Z', 'extras': []}
# I1120 01:52:33.172811 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 20.111258474669462, 'unit': None, 'global_step': 9, 'timestamp': '2018-11-20T01:52:33.172742Z', 'extras': []}
# I1120 01:52:33.173038 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.62151407111773, 'unit': None, 'global_step': 9, 'timestamp': '2018-11-20T01:52:33.173002Z', 'extras': []}
# I1120 01:52:33.173252 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 9, 'timestamp': '2018-11-20T01:52:33.173150Z', 'extras': []}
# I1120 01:52:33.173400 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 9, 'timestamp': '2018-11-20T01:52:33.173366Z', 'extras': []}
# I1120 01:52:33.907240 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 21.25572599470587, 'unit': None, 'global_step': 10, 'timestamp': '2018-11-20T01:52:33.907172Z', 'extras': []}
# I1120 01:52:33.907464 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.5712145933252, 'unit': None, 'global_step': 10, 'timestamp': '2018-11-20T01:52:33.907429Z', 'extras': []}
# I1120 01:52:33.907626 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 10, 'timestamp': '2018-11-20T01:52:33.907591Z', 'extras': []}
# I1120 01:52:33.907813 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 10, 'timestamp': '2018-11-20T01:52:33.907780Z', 'extras': []}
# I1120 01:52:33.269599 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 27.215266680721975, 'unit': None, 'global_step': 20, 'timestamp': '2018-11-20T01:52:33.269507Z', 'extras': []}
# I1120 01:52:33.269869 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.62834856981629, 'unit': None, 'global_step': 20, 'timestamp': '2018-11-20T01:52:33.269834Z', 'extras': []}
# I1120 01:52:33.270038 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 20, 'timestamp': '2018-11-20T01:52:33.270004Z', 'extras': []}
# I1120 01:52:33.270192 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 20, 'timestamp': '2018-11-20T01:52:33.270157Z', 'extras': []}
# I1120 01:52:34.003106 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 27.711658158303003, 'unit': None, 'global_step': 21, 'timestamp': '2018-11-20T01:52:34.003015Z', 'extras': []}
# I1120 01:52:34.003395 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.62590945731596, 'unit': None, 'global_step': 21, 'timestamp': '2018-11-20T01:52:34.003363Z', 'extras': []}
# I1120 01:52:34.003560 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 21, 'timestamp': '2018-11-20T01:52:34.003526Z', 'extras': []}
# I1120 01:52:34.003712 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 21, 'timestamp': '2018-11-20T01:52:34.003680Z', 'extras': []}
# I1120 01:52:34.640130 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 22.295903643918656, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:34.640061Z', 'extras': []}
# I1120 01:52:34.640358 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.66296513052103, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:34.640323Z', 'extras': []}
# I1120 01:52:34.640505 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:34.640472Z', 'extras': []}
# I1120 01:52:34.640655 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 11, 'timestamp': '2018-11-20T01:52:34.640622Z', 'extras': []}
# I1120 01:52:34.737684 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 28.17770000998075, 'unit': None, 'global_step': 22, 'timestamp': '2018-11-20T01:52:34.737590Z', 'extras': []}
# I1120 01:52:34.737963 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.5626446757381, 'unit': None, 'global_step': 22, 'timestamp': '2018-11-20T01:52:34.737920Z', 'extras': []}
# I1120 01:52:34.738116 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 22, 'timestamp': '2018-11-20T01:52:34.738082Z', 'extras': []}
# I1120 01:52:34.738316 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 22, 'timestamp': '2018-11-20T01:52:34.738281Z', 'extras': []}
# I1120 01:52:35.376448 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 23.238958829579513, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:35.376381Z', 'extras': []}
# I1120 01:52:35.376665 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.45920959369711, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:35.376637Z', 'extras': []}
# I1120 01:52:35.376868 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:35.376833Z', 'extras': []}
# I1120 01:52:35.377004 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 12, 'timestamp': '2018-11-20T01:52:35.376972Z', 'extras': []}
# I1120 01:52:35.470324 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 28.619265772028996, 'unit': None, 'global_step': 23, 'timestamp': '2018-11-20T01:52:35.470234Z', 'extras': []}
# I1120 01:52:35.470606 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.677301867267175, 'unit': None, 'global_step': 23, 'timestamp': '2018-11-20T01:52:35.470571Z', 'extras': []}
# I1120 01:52:35.470789 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 23, 'timestamp': '2018-11-20T01:52:35.470753Z', 'extras': []}
# I1120 01:52:35.470942 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 23, 'timestamp': '2018-11-20T01:52:35.470908Z', 'extras': []}
# I1120 01:52:36.111659 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 24.103106559634053, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:36.111590Z', 'extras': []}
# I1120 01:52:36.111925 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.52498269932101, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:36.111889Z', 'extras': []}
# I1120 01:52:36.112079 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:36.112044Z', 'extras': []}
# I1120 01:52:36.112213 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 13, 'timestamp': '2018-11-20T01:52:36.112182Z', 'extras': []}
# I1120 01:52:36.842920 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 24.902101957828847, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:36.842854Z', 'extras': []}
# I1120 01:52:36.843139 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.7598961899359, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:36.843109Z', 'extras': []}
# I1120 01:52:36.843298 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:36.843264Z', 'extras': []}
# I1120 01:52:36.843445 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 14, 'timestamp': '2018-11-20T01:52:36.843414Z', 'extras': []}
# I1120 01:52:36.204903 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 29.034249922777544, 'unit': None, 'global_step': 24, 'timestamp': '2018-11-20T01:52:36.204812Z', 'extras': []}
# I1120 01:52:36.205257 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.56251742513965, 'unit': None, 'global_step': 24, 'timestamp': '2018-11-20T01:52:36.205220Z', 'extras': []}
# I1120 01:52:36.205419 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 24, 'timestamp': '2018-11-20T01:52:36.205384Z', 'extras': []}
# I1120 01:52:36.205568 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 24, 'timestamp': '2018-11-20T01:52:36.205534Z', 'extras': []}
# I1120 01:52:36.938487 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 29.42787962333255, 'unit': None, 'global_step': 25, 'timestamp': '2018-11-20T01:52:36.938397Z', 'extras': []}
# I1120 01:52:36.938769 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.621301413604996, 'unit': None, 'global_step': 25, 'timestamp': '2018-11-20T01:52:36.938734Z', 'extras': []}
# I1120 01:52:36.938952 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 25, 'timestamp': '2018-11-20T01:52:36.938918Z', 'extras': []}
# I1120 01:52:36.939107 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 25, 'timestamp': '2018-11-20T01:52:36.939073Z', 'extras': []}
# ...
# I1120 01:53:11.301566 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 55, 'timestamp': '2018-11-20T01:53:11.301512Z', 'extras': []}
# I1120 01:53:11.301824 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 55, 'timestamp': '2018-11-20T01:53:11.301782Z', 'extras': []}
# I1120 01:53:12.038611 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 33.69299610103227, 'unit': None, 'global_step': 56, 'timestamp': '2018-11-20T01:53:12.038533Z', 'extras': []}
# I1120 01:53:12.038831 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.374899656278316, 'unit': None, 'global_step': 56, 'timestamp': '2018-11-20T01:53:12.038803Z', 'extras': []}
# I1120 01:53:12.038986 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step':
0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:15.566017Z', 'extras': []}
# #015 1/32 [..............................] - ETA: 23s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2/32 [>.............................] - ETA: 22s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3/32 [=>............................] - ETA: 21s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4/32 [==>...........................] - ETA: 20s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5/32 [===>..........................] - ETA: 19s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010
# I1120 01:53:16.456231 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 34.44220397248554, 'unit': None, 'global_step': 62, 'timestamp': '2018-11-20T01:53:16.456154Z', 'extras': []}
# I1120 01:53:16.456466 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.394266311841996, 'unit': None, 'global_step': 62, 'timestamp': '2018-11-20T01:53:16.456432Z', 'extras': []}
# I1120 01:53:16.456623 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 62, 'timestamp': '2018-11-20T01:53:16.456589Z', 'extras': []}
# I1120 01:53:16.456753 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 62, 'timestamp': '2018-11-20T01:53:16.456728Z', 'extras': []}
# I1120 01:53:17.192934 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 34.55578444806939, 'unit': None, 'global_step': 63, 'timestamp': '2018-11-20T01:53:17.192854Z', 'extras': []}
# I1120 01:53:17.193157 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.43679050342157, 'unit': None, 'global_step': 63, 'timestamp': '2018-11-20T01:53:17.193130Z', 'extras': []}
# I1120 01:53:17.193307 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 63, 'timestamp': '2018-11-20T01:53:17.193277Z', 'extras': []}
# I1120 01:53:17.193451 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 63, 'timestamp': '2018-11-20T01:53:17.193418Z', 'extras': []}
# I1120 01:53:17.930896 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'average_examples_per_sec', 'value': 34.66580399948035, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:17.930803Z', 'extras': []}
# I1120 01:53:17.931182 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'current_examples_per_sec', 'value': 43.36374468525052, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:17.931147Z', 'extras': []}
# I1120 01:53:17.931336 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:17.931305Z', 'extras': []}
# I1120 01:53:17.931474 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:17.931443Z', 'extras': []}
# I1120 01:53:17.675308 140126770882304 tf_logging.py:115] Logging the evaluation results...
# I1120 01:53:17.676085 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'accuracy', 'value': 1.0, 'unit': None, 'global_step': 2.0, 'timestamp': '2018-11-20T01:53:17.675682Z', 'extras': []}
# I1120 01:53:17.676317 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'loss', 'value': 0.0, 'unit': None, 'global_step': 2.0, 'timestamp': '2018-11-20T01:53:17.676236Z', 'extras': []}
# I1120 01:53:17.676562 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'accuracy', 'value': 1.0, 'unit': None, 'global_step': 4.0, 'timestamp': '2018-11-20T01:53:17.676450Z', 'extras': []}
# I1120 01:53:17.676956 140126770882304 tf_logging.py:115] Benchmark metric: {'name': 'loss', 'value': 0.0, 'unit': None, 'global_step': 4.0, 'timestamp': '2018-11-20T01:53:17.676656Z', 'extras': []}
#
# 2018-11-20 01:53:29 Uploading - Uploading generated training model2018-11-20 01:53:20,589 sagemaker-containers INFO     Reporting training SUCCESS
# I1120 01:53:22.150744 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_loss', 'value': 0.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:22.150089Z', 'extras': []}
# I1120 01:53:22.150988 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'train_accuracy', 'value': 1.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:22.150950Z', 'extras': []}
# I1120 01:53:22.151132 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'loss', 'value': 0.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:22.151100Z', 'extras': []}
# I1120 01:53:22.151274 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'accuracy', 'value': 1.0, 'unit': None, 'global_step': 64, 'timestamp': '2018-11-20T01:53:22.151241Z', 'extras': []}
# #015 1/32 [..............................] - ETA: 24s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2/32 [>.............................] - ETA: 22s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3/32 [=>............................] - ETA: 21s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4/32 [==>...........................] - ETA: 20s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5/32 [===>..........................] - ETA: 20s - loss: 0.0000e+00 - acc: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010
# I1120 01:53:24.005464 140218971571968 tf_logging.py:115] Logging the evaluation results...
# I1120 01:53:24.006041 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'accuracy', 'value': 1.0, 'unit': None, 'global_step': 2.0, 'timestamp': '2018-11-20T01:53:24.005738Z', 'extras': []}
# I1120 01:53:24.006232 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'loss', 'value': 0.0, 'unit': None, 'global_step': 2.0, 'timestamp': '2018-11-20T01:53:24.006164Z', 'extras': []}
# I1120 01:53:24.006430 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'accuracy', 'value': 1.0, 'unit': None, 'global_step': 4.0, 'timestamp': '2018-11-20T01:53:24.006374Z', 'extras': []}
# I1120 01:53:24.006627 140218971571968 tf_logging.py:115] Benchmark metric: {'name': 'loss', 'value': 0.0, 'unit': None, 'global_step': 4.0, 'timestamp': '2018-11-20T01:53:24.006532Z', 'extras': []}
# 2018-11-20 01:53:26,312 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2018-11-20 01:53:35 Completed - Training job completed
# Billable seconds: 264

# %% [markdown]
# The **```fit```** method will create a training job named **```tensorboard-example-{unique identifier}```** in two **ml.c4.xlarge** instances. These instances will write checkpoints to the s3 bucket **```sagemaker-{your aws account number}```**.
#
# If you don't have this bucket yet, **```sagemaker_session```** will create it for you. These checkpoints can be used for restoring the training job, and to analyze training job metrics using **TensorBoard**.
#
# The parameter **```run_tensorboard_locally=True```** will run **TensorBoard** in the machine that this notebook is running. Everytime a new checkpoint is created by the training job in the S3 bucket, **```fit```** will download the checkpoint to the temp folder that **TensorBoard** is pointing to.
#
# When the **```fit```** method starts the training, it will log the port that **TensorBoard** is using to display the metrics. The default port is **6006**, but another port can be choosen depending on its availability. The port number will increase until finds an available port. After that the port number will printed in stdout.
#
# It takes a few minutes to provision containers and start the training job.**TensorBoard** will start to display metrics shortly after that.
#
# You can access **TensorBoard** locally at [http://localhost:6006](http://localhost:6006) or using your SageMaker notebook instance [proxy/6006/](/proxy/6006/)(TensorBoard will not work if forget to put the slash, '/', in end of the url). If TensorBoard started on a different port, adjust these URLs to match.This example uses the optional hyperparameter **```throttle_secs```** to generate training evaluations more often, allowing to visualize **TensorBoard** scalar data faster. You can find the available optional hyperparameters [here](https://github.com/aws/sagemaker-python-sdk#optional-hyperparameters).

# %% [markdown]
# # Deploy the trained model to prepare for predictions
#
# The deploy() method creates an endpoint which serves prediction requests in real-time.

# %%
predictor = estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')

# %% [markdown]
# # Make a prediction with fake data to verify the endpoint is up
#
# Prediction is not the focus of this notebook, so to verify the endpoint's functionality, we'll simply generate random data in the correct shape and make a prediction.

# %%
import numpy as np

random_image_data = np.random.rand(32, 32, 3)
predictor.predict(random_image_data)

# %% [markdown]
# # Cleaning up
# To avoid incurring charges to your AWS account for the resources used in this tutorial you need to delete the **SageMaker Endpoint:**

# %%
sagemaker.Session().delete_endpoint(predictor.endpoint)
